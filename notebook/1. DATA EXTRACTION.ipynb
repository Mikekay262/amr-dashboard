# %% [markdown]
# ## Antimicrobial Resistance Indicator Dashboard

# %% [markdown]
# #### Life cycle of Machine learning Project
#
# - Understanding the Problem Statement
# - Data Collection
# - Data Checks to perform
# - Exploratory data analysis
# - Data Pre-Processing
# - Model Training
# - Choose best model

# %% [markdown]
# ### 1) Problem statement
# - This project aims to investigate and understand prevailing antimicrobial resistance patterns, report on indicators and examine the relationships between patient  .
#
#
# ### 2) Data Collection
# - TQMH HAMS data from
# - The data consists of 8 column and 1000 rows.

# %% [markdown]
# ### 2.1 Import Data and Required Packages
# ####  Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import camelot

# %% [markdown]
# #### Import the CSV Data as Pandas DataFrame

# %%
tables = camelot.read_pdf('data/EML.pdf',pages='1-end')
tables
# Out:
# <TableList n=56>

# %%
tables[13].df
# Out:
#                                                     0           1  \
# 0   Name of Drug\nFormulation\nStrength\nLevel \nN...
# 1                         1.1    General Anaesthetics
# 2                            Adrenaline (Epinephrine)   Injection
# 3                            Adrenaline (Epinephrine)   Injection
# 4                                            Atropine   Injection
# 5                                            Atropine   Injection
# 6                                         Bupivacaine   Injection
# 7                                         Bupivacaine   Injection
# 8                                         Bupivacaine   Injection
# 9                            Bupivacaine + Adrenaline   Injection
# 10                           Bupivacaine + Adrenaline   Injection
# 11                                           Diazepam   Injection
# 12                            Ephedrine Hydrochloride   Injection
# 13                                           Fentanyl   Injection
# ...
